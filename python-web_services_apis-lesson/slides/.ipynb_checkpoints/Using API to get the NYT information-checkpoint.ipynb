# %%
import pandas as pd 
import requests
import json
import pprint

# %%
'''Grabbing the NYT Articles using the API'''

nyt_base_url =  'https://api.nytimes.com/svc/search/v2/articlesearch.json'

params = {
'api_key' : 'e4ab2acea9404bdeaf27a83b9ab1862c'
} 

response = requests.get(nyt_base_url, params)
nyt_json = response.json()

# %%
'''Printing the out the Articles'''

pprint.pprint (nyt_json['response']['docs'])
# Out:
# [{'_id': '59fb74877c459f246b63249e',
#   'blog': {},
#   'byline': {'original': 'By THE ASSOCIATED PRESS'},
#   'document_type': 'article',
#   'headline': {'main': 'EPA to Hold Hearing on Climate Plan Repeal in West '
#                        'Virginia',
#                'print_headline': 'EPA to Hold Hearing on Climate Plan Repeal '
#                                  'in West Virginia'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:39:38+0000',
#   'score': 1.0,
#   'section_name': 'Politics',
#   'snippet': 'The Trump administration says it will hold a public hearing on '
#              'its intention to nullify an Obama-era plan to limit '
#              'planet-warming carbon emissions in a state that depends on coal '
#              'mining.',
#   'source': 'AP',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/c6e67ba1-5d09-57e9-af4e-14305e0424af',
#   'web_url': 'https://www.nytimes.com/aponline/2017/11/02/us/politics/ap-us-trump-climate-plan-repeal.html',
#   'word_count': 130},
#  {'_id': '59fb74767c459f246b63249d',
#   'blog': {},
#   'byline': {'original': 'By REUTERS'},
#   'document_type': 'article',
#   'headline': {'main': 'Serbian Foreign Minister Rejects US Call to Choose '
#                        'Between Russia and the West',
#                'print_headline': 'Serbian Foreign Minister Rejects US Call to '
#                                  'Choose Between Russia and the West'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:39:28+0000',
#   'score': 1.0,
#   'section_name': 'Europe',
#   'snippet': 'Serbia wants to maintain its delicate balancing act between '
#              'Russia and the West, its foreign minister said on Thursday, '
#              'dismissing U.S. calls for it to pick a side.',
#   'source': 'Reuters',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/b47d757e-c404-5daf-84f9-7a5921fa248f',
#   'web_url': 'https://www.nytimes.com/reuters/2017/11/02/world/europe/02reuters-serbia-minister.html',
#   'word_count': 371},
#  {'_id': '59fb744e7c459f246b63249c',
#   'blog': {},
#   'byline': {'original': 'By CEYLAN YEGINSU'},
#   'document_type': 'article',
#   'headline': {'main': 'Con Man Pleads Guilty to Fraud in Grenfell Tower Fire',
#                'print_headline': 'Con Man Pleads Guilty to Fraud in Grenfell '
#                                  'Tower Fire'},
#   'keywords': [{'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Grenfell Tower Fire (June, 2017)'},
#                {'isMajor': 'N',
#                 'name': 'glocations',
#                 'rank': 2,
#                 'value': 'London (England)'},
#                {'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Frauds and Swindling'},
#                {'isMajor': 'N',
#                 'name': 'organizations',
#                 'rank': 4,
#                 'value': 'Grenfell Tower (London, England)'}],
#   'multimedia': [],
#   'new_desk': 'Foreign',
#   'pub_date': '2017-11-02T19:38:44+0000',
#   'score': 1.0,
#   'section_name': 'Europe',
#   'snippet': 'The man, who has 28 prior convictions, duped relief officials '
#              'with a tale of losing his wife and 12-year-old son in the London '
#              'blaze in June.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/a8283ac4-e0e4-5b1a-83a7-76d37fd96e39',
#   'web_url': 'https://www.nytimes.com/2017/11/02/world/europe/grenfell-fire-fraud.html',
#   'word_count': 408},
#  {'_id': '59fb73e37c459f246b63249b',
#   'blog': {},
#   'byline': {'original': 'By THE ASSOCIATED PRESS'},
#   'document_type': 'article',
#   'headline': {'main': 'Midway Through NFL Season, Football Ratings Are Down',
#                'print_headline': 'Midway Through NFL Season, Football Ratings '
#                                  'Are Down'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:36:47+0000',
#   'score': 1.0,
#   'snippet': 'Midway through a season remembered most for protests by some '
#              'players during the National Anthem, viewership for NFL football '
#              'games is down 5 percent from last year.',
#   'source': 'AP',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/b60dc3c8-1fd1-5e10-bd70-b11b16a72e14',
#   'web_url': 'https://www.nytimes.com/aponline/2017/11/02/us/ap-us-bc-tv-football-viewing.html',
#   'word_count': 106},
#  {'_id': '59fb73697c459f246b63249a',
#   'blog': {},
#   'byline': {'original': 'By STEPHEN WILLIAMS'},
#   'document_type': 'article',
#   'headline': {'kicker': 'Wheels',
#                'main': 'Wheels Drive Auto Industry Forward, in Showrooms and '
#                        'Aftermarket Shops',
#                'print_headline': 'Wheels Drive Auto Industry Forward, in '
#                                  'Showrooms and Aftermarket Shops'},
#   'keywords': [{'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Automobiles'},
#                {'isMajor': 'N',
#                 'name': 'organizations',
#                 'rank': 2,
#                 'value': 'Mercedes-Benz'},
#                {'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Antique and Classic Cars'}],
#   'multimedia': [{'height': 450,
#                   'legacy': {'xlarge': 'images/2017/11/03/business/03WHEELS/03WHEELS-articleLarge.jpg',
#                              'xlargeheight': 450,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2017/11/03/business/03WHEELS/03WHEELS-articleLarge.jpg',
#                   'width': 600},
#                  {'height': 126,
#                   'legacy': {'wide': 'images/2017/11/03/business/03WHEELS/03WHEELS-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2017/11/03/business/03WHEELS/03WHEELS-thumbWide.jpg',
#                   'width': 190},
#                  {'height': 75,
#                   'legacy': {'thumbnail': 'images/2017/11/03/business/03WHEELS/03WHEELS-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2017/11/03/business/03WHEELS/03WHEELS-thumbStandard.jpg',
#                   'width': 75}],
#   'new_desk': 'Business',
#   'pub_date': '2017-11-02T19:34:55+0000',
#   'score': 1.0,
#   'section_name': 'Wheels',
#   'snippet': 'Be they understated and utilitarian or exotic and outrageous, a '
#              'fresh set of rims can make any car look new — even a new one.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/e9286d24-82f9-53fe-b2fa-47428263f7c6',
#   'web_url': 'https://www.nytimes.com/2017/11/02/automobiles/wheels/wheels-rims-aftermarket.html',
#   'word_count': 1118},
#  {'_id': '59fb729e7c459f246b632499',
#   'blog': {},
#   'byline': {'original': 'By THE ASSOCIATED PRESS'},
#   'document_type': 'article',
#   'headline': {'main': "After the Fed's Great Unwind Begins, the Stock Market "
#                        'Yawns',
#                'print_headline': "After the Fed's Great Unwind Begins, the "
#                                  'Stock Market Yawns'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:31:06+0000',
#   'score': 1.0,
#   'snippet': "The first month is in the books for the Federal Reserve's "
#              'yearslong process of pulling the plug on its bond-purchase '
#              'program, and markets took things in stride.',
#   'source': 'AP',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/9299a909-041a-57ce-82c7-728effa07655',
#   'web_url': 'https://www.nytimes.com/aponline/2017/11/02/business/ap-us-of-mutual-interest-following-the-fed.html',
#   'word_count': 896},
#  {'_id': '59fb726c7c459f246b632498',
#   'blog': {},
#   'byline': {'original': 'By REUTERS'},
#   'document_type': 'article',
#   'headline': {'main': 'Yellen Put Economy on Firmer Ground, Steered Fed Away '
#                        'From Crisis Era',
#                'print_headline': 'Yellen Put Economy on Firmer Ground, Steered '
#                                  'Fed Away From Crisis Era'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:30:29+0000',
#   'score': 1.0,
#   'snippet': 'Federal Reserve Chair Janet Yellen will depart as head of the '
#              "world's most powerful central bank after four years, during "
#              'which she has put the U.S. economy on a much firmer footing and '
#              'steered monetary policy away from the crisis era.',
#   'source': 'Reuters',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/a9c8c779-cd81-5003-8280-77ec39e6e313',
#   'web_url': 'https://www.nytimes.com/reuters/2017/11/02/business/02reuters-usa-trump-fed-yellen.html',
#   'word_count': 847},
#  {'_id': '59fb72177c459f246b632497',
#   'blog': {},
#   'byline': {'original': 'By EMILY PARKER'},
#   'document_type': 'article',
#   'headline': {'kicker': 'Op-Ed Contributor',
#                'main': 'Silicon Valley Can’t Destroy Democracy Without Our '
#                        'Help',
#                'print_headline': 'Silicon Valley Can’t Destroy Democracy '
#                                  'Without Our Help'},
#   'keywords': [{'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Social Media'},
#                {'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'News and News Media'},
#                {'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Cyberwarfare and Defense'},
#                {'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Russian Interference in 2016 US Elections and Ties '
#                          'to Trump Associates'},
#                {'isMajor': 'N',
#                 'name': 'organizations',
#                 'rank': 5,
#                 'value': 'Facebook Inc'},
#                {'isMajor': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': 'Twitter'},
#                {'isMajor': 'N',
#                 'name': 'subject',
#                 'rank': 7,
#                 'value': 'Computers and the Internet'}],
#   'multimedia': [{'height': 390,
#                   'legacy': {'xlarge': 'images/2017/11/03/opinion/03parkerSub/03parkerSub-articleLarge.jpg',
#                              'xlargeheight': 390,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2017/11/03/opinion/03parkerSub/03parkerSub-articleLarge.jpg',
#                   'width': 600},
#                  {'height': 126,
#                   'legacy': {'wide': 'images/2017/11/03/opinion/03parkerSub/03parkerSub-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2017/11/03/opinion/03parkerSub/03parkerSub-thumbWide.jpg',
#                   'width': 190},
#                  {'height': 75,
#                   'legacy': {'thumbnail': 'images/2017/11/03/opinion/03parkerSub/03parkerSub-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2017/11/03/opinion/03parkerSub/03parkerSub-thumbStandard.jpg',
#                   'width': 75}],
#   'new_desk': 'OpEd',
#   'pub_date': '2017-11-02T19:29:19+0000',
#   'score': 1.0,
#   'snippet': 'With Russian meddling making headlines, it’s trendy to bash '
#              'social media companies. Instead, we should look in the mirror.',
#   'source': 'The New York Times',
#   'type_of_material': 'Op-Ed',
#   'uri': 'nyt://article/28b55e79-9095-5214-810b-8512fe5865b3',
#   'web_url': 'https://www.nytimes.com/2017/11/02/opinion/silicon-valley-democracy-russia.html',
#   'word_count': 875},
#  {'_id': '59fb71ce7c459f246b632495',
#   'blog': {},
#   'byline': {'original': 'By THE ASSOCIATED PRESS'},
#   'document_type': 'article',
#   'headline': {'main': 'Auriemma Thinks Pitino Should Get Another Chance to '
#                        'Coach',
#                'print_headline': 'Auriemma Thinks Pitino Should Get Another '
#                                  'Chance to Coach'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:27:44+0000',
#   'score': 1.0,
#   'section_name': 'College Basketball',
#   'snippet': 'Geno Auriemma thinks Rick Pitino should get another chance to '
#              "coach and that he's already suffered enough by losing his job at "
#              'Louisville.',
#   'source': 'AP',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/980ee073-e9be-59ed-b47b-1b4abca9f953',
#   'web_url': 'https://www.nytimes.com/aponline/2017/11/02/sports/ncaabasketball/ap-bkw-auriemma-pitino.html',
#   'word_count': 689},
#  {'_id': '59fb71d37c459f246b632496',
#   'blog': {},
#   'byline': {'original': 'By THE ASSOCIATED PRESS'},
#   'document_type': 'article',
#   'headline': {'main': "A Snapshot of Jerome Powell, Trump's Pick to Be Fed "
#                        'Chair',
#                'print_headline': "A Snapshot of Jerome Powell, Trump's Pick to "
#                                  'Be Fed Chair'},
#   'keywords': [],
#   'multimedia': [],
#   'new_desk': 'None',
#   'pub_date': '2017-11-02T19:27:39+0000',
#   'score': 1.0,
#   'snippet': 'NAME: Jerome H. "Jay" Powell',
#   'source': 'AP',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/313dfdf8-a4b7-5b76-8513-2a802a24950a',
#   'web_url': 'https://www.nytimes.com/aponline/2017/11/02/us/ap-us-jerome-powell-bio-box.html',
#   'word_count': 137}]

# %%
nyt_article_list = nyt_json['response']['docs']

# %%
'''Loading the JSON into a Pandas Dataframe '''
nyt_df = pd.DataFrame(nyt_article_list)

# %%
'''Validating the results using the head command'''
nyt_df.head()
# Out:
#                         _id blog                                   byline  \
# 0  59fb74877c459f246b63249e   {}  {'original': 'By THE ASSOCIATED PRESS'}
# 1  59fb74767c459f246b63249d   {}               {'original': 'By REUTERS'}
# 2  59fb744e7c459f246b63249c   {}        {'original': 'By CEYLAN YEGINSU'}
# 3  59fb73e37c459f246b63249b   {}  {'original': 'By THE ASSOCIATED PRESS'}
# 4  59fb73697c459f246b63249a   {}      {'original': 'By STEPHEN WILLIAMS'}
#
#   document_type                                           headline  \
# 0       article  {'main': 'EPA to Hold Hearing on Climate Plan ...
# 1       article  {'main': 'Serbian Foreign Minister Rejects US ...
# 2       article  {'main': 'Con Man Pleads Guilty to Fraud in Gr...
# 3       article  {'main': 'Midway Through NFL Season, Football ...
# 4       article  {'main': 'Wheels Drive Auto Industry Forward, ...
#
#                                             keywords  \
# 0                                                 []
# 1                                                 []
# 2  [{'isMajor': 'N', 'rank': 1, 'name': 'subject'...
# 3                                                 []
# 4  [{'isMajor': 'N', 'rank': 1, 'name': 'subject'...
#
#                                           multimedia  new_desk  \
# 0                                                 []      None
# 1                                                 []      None
# 2                                                 []   Foreign
# 3                                                 []      None
# 4  [{'type': 'image', 'subtype': 'xlarge', 'url':...  Business
#
#                    pub_date  score section_name  \
# 0  2017-11-02T19:39:38+0000    1.0     Politics
# 1  2017-11-02T19:39:28+0000    1.0       Europe
# 2  2017-11-02T19:38:44+0000    1.0       Europe
# 3  2017-11-02T19:36:47+0000    1.0          NaN
# 4  2017-11-02T19:34:55+0000    1.0       Wheels
#
#                                              snippet              source  \
# 0  The Trump administration says it will hold a p...                  AP
# 1  Serbia wants to maintain its delicate balancin...             Reuters
# 2  The man, who has 28 prior convictions, duped r...  The New York Times
# 3  Midway through a season remembered most for pr...                  AP
# 4  Be they understated and utilitarian or exotic ...  The New York Times
#
#   type_of_material                                                uri  \
# 0             News  nyt://article/c6e67ba1-5d09-57e9-af4e-14305e04...
# 1             News  nyt://article/b47d757e-c404-5daf-84f9-7a5921fa...
# 2             News  nyt://article/a8283ac4-e0e4-5b1a-83a7-76d37fd9...
# 3             News  nyt://article/b60dc3c8-1fd1-5e10-bd70-b11b16a7...
# 4             News  nyt://article/e9286d24-82f9-53fe-b2fa-47428263...
#
#                                              web_url  word_count
# 0  https://www.nytimes.com/aponline/2017/11/02/us...         130
# 1  https://www.nytimes.com/reuters/2017/11/02/wor...         371
# 2  https://www.nytimes.com/2017/11/02/world/europ...         408
# 3  https://www.nytimes.com/aponline/2017/11/02/us...         106
# 4  https://www.nytimes.com/2017/11/02/automobiles...        1118

# %%
'''Function to the clean the junk in the Headline column and '''
def clean_headline(headline):
    for k,v in headline.items():
        return clean_headline['print_headline']

# %%
# nyt_df['headline'] = nyt_df['headline'].apply(clean_headline)

# %%
for k,v in nyt_df['headline'][0].items():
    if k =='print_headline': 
        print (nyt_df['headline'][0][k])
    else: 
        continue
# Out:
# EPA to Hold Hearing on Climate Plan Repeal in West Virginia
